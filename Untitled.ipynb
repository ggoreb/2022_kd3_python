# %%
https://www.daangn.com/articles/402184749

# %%
https://www.daangn.com/region/%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C

# %%
import requests
res = requests.get('https://www.daangn.com/articles/402184749')
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="ko">\n<head>\n  <meta charset="utf-8">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no">\n  \n    <link rel="canonical" href="https://www.daangn.com/articles/402184749" />\n\n  <title>냉장고, 세탁기, 쇼차, 블라인... | 당근마켓 중고거래</title>\n<meta name="description" content="1.냉장고-3만 2.세탁기-3만 3.블라인더- 길이 약 170mm 1.5만 4.쇼파-쿠션 미 포함..." />\n<meta name="keywords" content="냉장고, 세탁기, 쇼, 차, 블라인드, 떨이" />\n<link rel="author" href="상하이" />\n<meta property="og:url" content="https://www.daangn.com/articles/402184749" />\n<meta property="og:title" content="냉장고, 세탁기, 쇼차, 블라인... | 당근마켓 중고거래" />\n<meta property="og:description" content="1.냉장고-3만\n\n2.세탁기-3만\n\n3.블라인더- 길이 약 170mm 1.5만\n\n4.쇼파-쿠션 미 포함..." />\n<meta property="og:site_name" content="당근마켓" />\n<meta property="og:image" content="https://dnvefa72aowie.cloudfront.net/origin/article/202205/2359E0DB043FE709EDEC0B10C96322
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text)

# %%
soup.select('#article-title')
# Out:
# [<h1 id="article-title" property="schema:name" style="margin-top:0px;">냉장고, 세탁기, 쇼차, 블라인드 떨이</h1>]

# %%
import requests
res = requests.get('https://www.daangn.com/region/%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C')
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="ko">\n<head>\n  <meta charset="utf-8">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no">\n  \n    <link rel="canonical" href="https://www.daangn.com/region/%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C" />\n\n  <title>서울특별시 중고거래 | 당신 근처의 당근마켓</title>\n<meta name="description" content="서울특별시에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." />\n<link rel="author" href="당근마켓" />\n<meta property="og:url" content="https://www.daangn.com/region/%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C" />\n<meta property="og:title" content="서울특별시 중고거래 | 당신 근처의 당근마켓" />\n<meta property="og:description" content="서울특별시에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." />\n<meta property="og:site_name" content="당근마켓" />\n<meta property="og:image" content="https://www.daangn.com/images/meta/home/flea_market.png" />\n<meta property="og:type" content=
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text)

# %%
tops = soup.select('.card-top')

# %%
tops[0].find('a').attrs['href']
# Out:
# '/articles/402184749'

# %%
for top in tops:
    href = top.find('a').attrs['href']
    print(href)
# Out:
# /articles/402184749
# /articles/403077267
# /articles/401106498
# /articles/401079751
# /articles/401669970
# /articles/403358805
# /articles/403025819
# /articles/402790915
# /articles/403324361
# /articles/403433815
# /articles/403423578
# /articles/403335882
# /articles/403366058
# /articles/403278323
# /articles/402305393
# /articles/403401527
# /articles/403443629
# /articles/402054074
# /articles/401210153
# /articles/403373923
# /articles/403478970
# /articles/400467778
# /articles/403437637
# /articles/403129484
# /articles/403369214
# /articles/403428791
# /articles/403400520
# /articles/401317563
# /articles/403407646
# /articles/403476548
# /articles/403189331
# /articles/403352475
# /articles/403420932
# /articles/402883365
# /articles/401968551
# /articles/403200502
# /articles/403438925
# /articles/402813492
# /articles/402315703
# /articles/400388480
# /articles/403414742
# /articles/401649517
# /articles/403366403
# /articles/403430463
# /articles/403148189
# ...
